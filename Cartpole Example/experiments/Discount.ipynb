# %% [markdown]
# # Module Five Assignment: Cartpole Problem
# Review the code in this notebook and in the score_logger.py file in the *scores* folder (directory). Once you have reviewed the code, return to this notebook and select **Cell** and then **Run All** from the menu bar to run this code. The code takes several minutes to run.

# %% [markdown]
# Note: If the code is running properly, you should begin to see output appearing above this code block. It will take several minutes, so it is recommended that you let this code run in the background while completing other work. When the code has finished, it will print output saying, "Solved in _ runs, _ total runs."
#
# You may see an error about not having an exit command. This error does not affect the program's functionality and results from the steps taken to convert the code from Python 2.x to Python 3. Please disregard this error.

# %%
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  
  
  
from scores.score_logger import ScoreLogger 

# modifying discount factor (GAMMA) from .95 to 1.2
ENV_NAME = "CartPole-v1"  
  
GAMMA =.92 # decreased from .95 I tried .99 it was too high
LEARNING_RATE = 0.001  
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 20  
  
EXPLORATION_MAX = 1.0  
EXPLORATION_MIN = 0.01  
EXPLORATION_DECAY = 0.995  
  
  
class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()

# %%
 cartpole()
# Out:
# Run: 1, exploration: 0.9091562615825302, score: 39
# Scores: (min: 39, avg: 39, max: 39)
#
# Run: 2, exploration: 0.8433051360508336, score: 16
# Scores: (min: 16, avg: 27.5, max: 39)
#
# Run: 3, exploration: 0.7901049725470279, score: 14
# Scores: (min: 14, avg: 23, max: 39)
#
# Run: 4, exploration: 0.7147372386831305, score: 21
# Scores: (min: 14, avg: 22.5, max: 39)
#
# Run: 5, exploration: 0.6629680834613705, score: 16
# Scores: (min: 14, avg: 21.2, max: 39)
#
# Run: 6, exploration: 0.6274028820538087, score: 12
# Scores: (min: 12, avg: 19.666666666666668, max: 39)
#
# Run: 7, exploration: 0.5848838636585911, score: 15
# Scores: (min: 12, avg: 19, max: 39)
#
# Run: 8, exploration: 0.547986285490042, score: 14
# Scores: (min: 12, avg: 18.375, max: 39)
#
# Run: 9, exploration: 0.5185893309484582, score: 12
# Scores: (min: 12, avg: 17.666666666666668, max: 39)
#
# Run: 10, exploration: 0.4883155414435353, score: 13
# Scores: (min: 12, avg: 17.2, max: 39)
#
# Run: 11, exploration: 0.4117990041127769, score: 35
# Scores: (min: 12, avg: 18.818181818181817, max: 39)
#
# Run: 12, exploration: 0.37627099809304654, score: 19
# Scores: (min: 12, avg: 18.833333333333332, max: 39)
#
# Run: 13, exploration: 0.3578751580867638, score: 11
# Scores: (min: 11, avg: 18.23076923076923, max: 39)
#
# Run: 14, exploration: 0.3386767948568688, score: 12
# Scores: (min: 11, avg: 17.785714285714285, max: 39)
#
# Run: 15, exploration: 0.3237376186352221, score: 10
# Scores: (min: 10, avg: 17.266666666666666, max: 39)
#
# Run: 16, exploration: 0.2987875242397482, score: 17
# Scores: (min: 10, avg: 17.25, max: 39)
#
# Run: 17, exploration: 0.2702863258025825, score: 21
# Scores: (min: 10, avg: 17.470588235294116, max: 39)
#
# Run: 18, exploration: 0.22566020663225933, score: 37
# Scores: (min: 10, avg: 18.555555555555557, max: 39)
#
# Run: 19, exploration: 0.16128775296900558, score: 68
# Scores: (min: 10, avg: 21.157894736842106, max: 68)
#
# Run: 20, exploration: 0.07528520976374668, score: 153
# Scores: (min: 10, avg: 27.75, max: 153)
#
# Run: 21, exploration: 0.04676299685992172, score: 96
# Scores: (min: 10, avg: 31, max: 153)
#
# Run: 22, exploration: 0.023181078627322618, score: 141
# Scores: (min: 10, avg: 36, max: 153)
#
# Run: 23, exploration: 0.013972200057807112, score: 102
# Scores: (min: 10, avg: 38.869565217391305, max: 153)
#
# Run: 24, exploration: 0.01, score: 86
# Scores: (min: 10, avg: 40.833333333333336, max: 153)
#
# Run: 25, exploration: 0.01, score: 90
# Scores: (min: 10, avg: 42.8, max: 153)
#
# Run: 26, exploration: 0.01, score: 131
# Scores: (min: 10, avg: 46.19230769230769, max: 153)
#
# Run: 27, exploration: 0.01, score: 121
# Scores: (min: 10, avg: 48.96296296296296, max: 153)
#
# Run: 28, exploration: 0.01, score: 202
# Scores: (min: 10, avg: 54.42857142857143, max: 202)
#
# Run: 29, exploration: 0.01, score: 280
# Scores: (min: 10, avg: 62.206896551724135, max: 280)
#
# Run: 30, exploration: 0.01, score: 227
# Scores: (min: 10, avg: 67.7, max: 280)
#
# Run: 31, exploration: 0.01, score: 128
# Scores: (min: 10, avg: 69.64516129032258, max: 280)
#
# Run: 32, exploration: 0.01, score: 108
# Scores: (min: 10, avg: 70.84375, max: 280)
#
# Run: 33, exploration: 0.01, score: 118
# Scores: (min: 10, avg: 72.27272727272727, max: 280)
#
# Run: 34, exploration: 0.01, score: 183
# Scores: (min: 10, avg: 75.52941176470588, max: 280)
#
# Run: 35, exploration: 0.01, score: 141
# Scores: (min: 10, avg: 77.4, max: 280)
#
# Run: 36, exploration: 0.01, score: 189
# Scores: (min: 10, avg: 80.5, max: 280)
#
# Run: 37, exploration: 0.01, score: 161
# Scores: (min: 10, avg: 82.67567567567568, max: 280)
#
# Run: 38, exploration: 0.01, score: 161
# Scores: (min: 10, avg: 84.73684210526316, max: 280)
#
# Run: 39, exploration: 0.01, score: 171
# Scores: (min: 10, avg: 86.94871794871794, max: 280)
#
# Run: 40, exploration: 0.01, score: 108
# Scores: (min: 10, avg: 87.475, max: 280)
#
# Run: 41, exploration: 0.01, score: 142
# Scores: (min: 10, avg: 88.8048780487805, max: 280)
#
# Run: 42, exploration: 0.01, score: 152
# Scores: (min: 10, avg: 90.30952380952381, max: 280)
#
# Run: 43, exploration: 0.01, score: 179
# Scores: (min: 10, avg: 92.37209302325581, max: 280)
#
# Run: 44, exploration: 0.01, score: 285
# Scores: (min: 10, avg: 96.75, max: 285)
#
# Run: 45, exploration: 0.01, score: 119
# Scores: (min: 10, avg: 97.24444444444444, max: 285)
#
# Run: 46, exploration: 0.01, score: 188
# Scores: (min: 10, avg: 99.21739130434783, max: 285)
#
# Run: 47, exploration: 0.01, score: 207
# Scores: (min: 10, avg: 101.51063829787235, max: 285)
#
# Run: 48, exploration: 0.01, score: 207
# Scores: (min: 10, avg: 103.70833333333333, max: 285)
#
# Run: 49, exploration: 0.01, score: 127
# Scores: (min: 10, avg: 104.18367346938776, max: 285)
#
# Run: 50, exploration: 0.01, score: 157
# Scores: (min: 10, avg: 105.24, max: 285)
#
# Run: 51, exploration: 0.01, score: 306
# Scores: (min: 10, avg: 109.17647058823529, max: 306)
#
# Run: 52, exploration: 0.01, score: 133
# Scores: (min: 10, avg: 109.63461538461539, max: 306)
#
# Run: 53, exploration: 0.01, score: 206
# Scores: (min: 10, avg: 111.45283018867924, max: 306)
#
# Run: 54, exploration: 0.01, score: 108
# Scores: (min: 10, avg: 111.38888888888889, max: 306)
#
# Run: 55, exploration: 0.01, score: 163
# Scores: (min: 10, avg: 112.32727272727273, max: 306)
#
# Run: 56, exploration: 0.01, score: 122
# Scores: (min: 10, avg: 112.5, max: 306)
#
# Run: 57, exploration: 0.01, score: 143
# Scores: (min: 10, avg: 113.03508771929825, max: 306)
#
# Run: 58, exploration: 0.01, score: 95
# Scores: (min: 10, avg: 112.72413793103448, max: 306)
#
# Run: 59, exploration: 0.01, score: 109
# Scores: (min: 10, avg: 112.66101694915254, max: 306)
#
# Run: 60, exploration: 0.01, score: 99
# Scores: (min: 10, avg: 112.43333333333334, max: 306)
#
# Run: 61, exploration: 0.01, score: 178
# Scores: (min: 10, avg: 113.50819672131148, max: 306)
#
# Run: 62, exploration: 0.01, score: 287
# Scores: (min: 10, avg: 116.30645161290323, max: 306)
#
# Run: 63, exploration: 0.01, score: 109
# Scores: (min: 10, avg: 116.19047619047619, max: 306)
#
# Run: 64, exploration: 0.01, score: 158
# Scores: (min: 10, avg: 116.84375, max: 306)
#
# Run: 65, exploration: 0.01, score: 500
# Scores: (min: 10, avg: 122.73846153846154, max: 500)
#
# Run: 66, exploration: 0.01, score: 152
# Scores: (min: 10, avg: 123.18181818181819, max: 500)
#
# Run: 67, exploration: 0.01, score: 146
# Scores: (min: 10, avg: 123.5223880597015, max: 500)
#
# Run: 68, exploration: 0.01, score: 311
# Scores: (min: 10, avg: 126.27941176470588, max: 500)
#
# Run: 69, exploration: 0.01, score: 110
# Scores: (min: 10, avg: 126.04347826086956, max: 500)
#
# Run: 70, exploration: 0.01, score: 135
# Scores: (min: 10, avg: 126.17142857142858, max: 500)
#
# Run: 71, exploration: 0.01, score: 127
# Scores: (min: 10, avg: 126.1830985915493, max: 500)
#
# Run: 72, exploration: 0.01, score: 249
# Scores: (min: 10, avg: 127.88888888888889, max: 500)
#
# Run: 73, exploration: 0.01, score: 265
# Scores: (min: 10, avg: 129.76712328767124, max: 500)
#
# Run: 74, exploration: 0.01, score: 149
# Scores: (min: 10, avg: 130.02702702702703, max: 500)
#
# Run: 75, exploration: 0.01, score: 182
# Scores: (min: 10, avg: 130.72, max: 500)
#
# Run: 76, exploration: 0.01, score: 111
# Scores: (min: 10, avg: 130.46052631578948, max: 500)
#
# Run: 77, exploration: 0.01, score: 176
# Scores: (min: 10, avg: 131.05194805194805, max: 500)
#
# Run: 78, exploration: 0.01, score: 174
# Scores: (min: 10, avg: 131.60256410256412, max: 500)
#
# Run: 79, exploration: 0.01, score: 275
# Scores: (min: 10, avg: 133.41772151898735, max: 500)
#
# Run: 80, exploration: 0.01, score: 284
# Scores: (min: 10, avg: 135.3, max: 500)
#
# Run: 81, exploration: 0.01, score: 144
# Scores: (min: 10, avg: 135.40740740740742, max: 500)
#
# Run: 82, exploration: 0.01, score: 191
# Scores: (min: 10, avg: 136.08536585365854, max: 500)
#
# Run: 83, exploration: 0.01, score: 104
# Scores: (min: 10, avg: 135.6987951807229, max: 500)
#
# Run: 84, exploration: 0.01, score: 97
# Scores: (min: 10, avg: 135.23809523809524, max: 500)
#
# Run: 85, exploration: 0.01, score: 282
# Scores: (min: 10, avg: 136.96470588235294, max: 500)
#
# Run: 86, exploration: 0.01, score: 194
# Scores: (min: 10, avg: 137.62790697674419, max: 500)
#
# Run: 87, exploration: 0.01, score: 104
# Scores: (min: 10, avg: 137.24137931034483, max: 500)
#
# Run: 88, exploration: 0.01, score: 166
# Scores: (min: 10, avg: 137.5681818181818, max: 500)
#
# Run: 89, exploration: 0.01, score: 99
# Scores: (min: 10, avg: 137.13483146067415, max: 500)
#
# Run: 90, exploration: 0.01, score: 146
# Scores: (min: 10, avg: 137.23333333333332, max: 500)
#
# Run: 91, exploration: 0.01, score: 136
# Scores: (min: 10, avg: 137.21978021978023, max: 500)
#
# Run: 92, exploration: 0.01, score: 131
# Scores: (min: 10, avg: 137.15217391304347, max: 500)
#
# Run: 93, exploration: 0.01, score: 192
# Scores: (min: 10, avg: 137.74193548387098, max: 500)
#
# Run: 94, exploration: 0.01, score: 159
# Scores: (min: 10, avg: 137.96808510638297, max: 500)
#
# Run: 95, exploration: 0.01, score: 153
# Scores: (min: 10, avg: 138.1263157894737, max: 500)
#
# Run: 96, exploration: 0.01, score: 128
# Scores: (min: 10, avg: 138.02083333333334, max: 500)
#
# Run: 97, exploration: 0.01, score: 182
# Scores: (min: 10, avg: 138.4742268041237, max: 500)
#
# Run: 98, exploration: 0.01, score: 290
# Scores: (min: 10, avg: 140.0204081632653, max: 500)
#
# Run: 99, exploration: 0.01, score: 168
# Scores: (min: 10, avg: 140.3030303030303, max: 500)
#
# Run: 100, exploration: 0.01, score: 209
# Scores: (min: 10, avg: 140.99, max: 500)
#
# Run: 101, exploration: 0.01, score: 77
# Scores: (min: 10, avg: 141.37, max: 500)
#
# Run: 102, exploration: 0.01, score: 254
# Scores: (min: 10, avg: 143.75, max: 500)
#
# Run: 103, exploration: 0.01, score: 210
# Scores: (min: 10, avg: 145.71, max: 500)
#
# Run: 104, exploration: 0.01, score: 153
# Scores: (min: 10, avg: 147.03, max: 500)
#
# Run: 105, exploration: 0.01, score: 155
# Scores: (min: 10, avg: 148.42, max: 500)
#
# Run: 106, exploration: 0.01, score: 146
# Scores: (min: 10, avg: 149.76, max: 500)
#
# Run: 107, exploration: 0.01, score: 104
# Scores: (min: 10, avg: 150.65, max: 500)
#
# Run: 108, exploration: 0.01, score: 259
# Scores: (min: 10, avg: 153.1, max: 500)
#
# Run: 109, exploration: 0.01, score: 151
# Scores: (min: 10, avg: 154.49, max: 500)
#
# Run: 110, exploration: 0.01, score: 288
# Scores: (min: 10, avg: 157.24, max: 500)
#
# Run: 111, exploration: 0.01, score: 118
# Scores: (min: 10, avg: 158.07, max: 500)
#
# Run: 112, exploration: 0.01, score: 235
# Scores: (min: 10, avg: 160.23, max: 500)
#
# Run: 113, exploration: 0.01, score: 141
# Scores: (min: 10, avg: 161.53, max: 500)
#
# Run: 114, exploration: 0.01, score: 201
# Scores: (min: 10, avg: 163.42, max: 500)
#
# Run: 115, exploration: 0.01, score: 225
# Scores: (min: 17, avg: 165.57, max: 500)
#
# Run: 116, exploration: 0.01, score: 211
# Scores: (min: 21, avg: 167.51, max: 500)
#
# Run: 117, exploration: 0.01, score: 90
# Scores: (min: 37, avg: 168.2, max: 500)
#
# Run: 118, exploration: 0.01, score: 128
# Scores: (min: 68, avg: 169.11, max: 500)
#
# Run: 119, exploration: 0.01, score: 133
# Scores: (min: 77, avg: 169.76, max: 500)
#
# Run: 120, exploration: 0.01, score: 114
# Scores: (min: 77, avg: 169.37, max: 500)
#
# Run: 121, exploration: 0.01, score: 151
# Scores: (min: 77, avg: 169.92, max: 500)
#
# Run: 122, exploration: 0.01, score: 261
# Scores: (min: 77, avg: 171.12, max: 500)
#
# Run: 123, exploration: 0.01, score: 245
# Scores: (min: 77, avg: 172.55, max: 500)
#
# Run: 124, exploration: 0.01, score: 119
# Scores: (min: 77, avg: 172.88, max: 500)
#
# Run: 125, exploration: 0.01, score: 152
# Scores: (min: 77, avg: 173.5, max: 500)
#
# Run: 126, exploration: 0.01, score: 110
# Scores: (min: 77, avg: 173.29, max: 500)
#
# Run: 127, exploration: 0.01, score: 185
# Scores: (min: 77, avg: 173.93, max: 500)
#
# Run: 128, exploration: 0.01, score: 96
# Scores: (min: 77, avg: 172.87, max: 500)
#
# Run: 129, exploration: 0.01, score: 126
# Scores: (min: 77, avg: 171.33, max: 500)
#
# Run: 130, exploration: 0.01, score: 153
# Scores: (min: 77, avg: 170.59, max: 500)
#
# Run: 131, exploration: 0.01, score: 175
# Scores: (min: 77, avg: 171.06, max: 500)
#
# Run: 132, exploration: 0.01, score: 108
# Scores: (min: 77, avg: 171.06, max: 500)
#
# Run: 133, exploration: 0.01, score: 164
# Scores: (min: 77, avg: 171.52, max: 500)
#
# Run: 134, exploration: 0.01, score: 265
# Scores: (min: 77, avg: 172.34, max: 500)
#
# Run: 135, exploration: 0.01, score: 195
# Scores: (min: 77, avg: 172.88, max: 500)
#
# Run: 136, exploration: 0.01, score: 163
# Scores: (min: 77, avg: 172.62, max: 500)
#
# Run: 137, exploration: 0.01, score: 129
# Scores: (min: 77, avg: 172.3, max: 500)
#
# Run: 138, exploration: 0.01, score: 148
# Scores: (min: 77, avg: 172.17, max: 500)
#
# Run: 139, exploration: 0.01, score: 123
# Scores: (min: 77, avg: 171.69, max: 500)
#
# Run: 140, exploration: 0.01, score: 142
# Scores: (min: 77, avg: 172.03, max: 500)
#
# Run: 141, exploration: 0.01, score: 137
# Scores: (min: 77, avg: 171.98, max: 500)
#
# Run: 142, exploration: 0.01, score: 377
# Scores: (min: 77, avg: 174.23, max: 500)
#
# Run: 143, exploration: 0.01, score: 383
# Scores: (min: 77, avg: 176.27, max: 500)
#
# Run: 144, exploration: 0.01, score: 198
# Scores: (min: 77, avg: 175.4, max: 500)
#
# Run: 145, exploration: 0.01, score: 128
# Scores: (min: 77, avg: 175.49, max: 500)
#
# Run: 146, exploration: 0.01, score: 226
# Scores: (min: 77, avg: 175.87, max: 500)
#
# Run: 147, exploration: 0.01, score: 118
# Scores: (min: 77, avg: 174.98, max: 500)
#
# Run: 148, exploration: 0.01, score: 186
# Scores: (min: 77, avg: 174.77, max: 500)
#
# Run: 149, exploration: 0.01, score: 221
# Scores: (min: 77, avg: 175.71, max: 500)
#
# Run: 150, exploration: 0.01, score: 146
# Scores: (min: 77, avg: 175.6, max: 500)
#
# Run: 151, exploration: 0.01, score: 126
# Scores: (min: 77, avg: 173.8, max: 500)
#
# Run: 152, exploration: 0.01, score: 243
# Scores: (min: 77, avg: 174.9, max: 500)
#
# Run: 153, exploration: 0.01, score: 142
# Scores: (min: 77, avg: 174.26, max: 500)
#
# Run: 154, exploration: 0.01, score: 153
# Scores: (min: 77, avg: 174.71, max: 500)
#
# Run: 155, exploration: 0.01, score: 29
# Scores: (min: 29, avg: 173.37, max: 500)
#
# Run: 156, exploration: 0.01, score: 236
# Scores: (min: 29, avg: 174.51, max: 500)
#
# Run: 157, exploration: 0.01, score: 147
# Scores: (min: 29, avg: 174.55, max: 500)
#
# Run: 158, exploration: 0.01, score: 113
# Scores: (min: 29, avg: 174.73, max: 500)
#
# Run: 159, exploration: 0.01, score: 113
# Scores: (min: 29, avg: 174.77, max: 500)
#
# Run: 160, exploration: 0.01, score: 500
# Scores: (min: 29, avg: 178.78, max: 500)
#
# Run: 161, exploration: 0.01, score: 210
# Scores: (min: 29, avg: 179.1, max: 500)
#
# Run: 162, exploration: 0.01, score: 173
# Scores: (min: 29, avg: 177.96, max: 500)
#
# Run: 163, exploration: 0.01, score: 161
# Scores: (min: 29, avg: 178.48, max: 500)
#
# Run: 164, exploration: 0.01, score: 213
# Scores: (min: 29, avg: 179.03, max: 500)
#
# Run: 165, exploration: 0.01, score: 252
# Scores: (min: 29, avg: 176.55, max: 500)
#
# Run: 166, exploration: 0.01, score: 420
# Scores: (min: 29, avg: 179.23, max: 500)
#
# Run: 167, exploration: 0.01, score: 161
# Scores: (min: 29, avg: 179.38, max: 500)
#
# Run: 168, exploration: 0.01, score: 90
# Scores: (min: 29, avg: 177.17, max: 500)
#
# Run: 169, exploration: 0.01, score: 102
# Scores: (min: 29, avg: 177.09, max: 500)
#
# Run: 170, exploration: 0.01, score: 104
# Scores: (min: 29, avg: 176.78, max: 500)
#
# Run: 171, exploration: 0.01, score: 366
# Scores: (min: 29, avg: 179.17, max: 500)
#
# Run: 172, exploration: 0.01, score: 192
# Scores: (min: 29, avg: 178.6, max: 500)
#
# Run: 173, exploration: 0.01, score: 262
# Scores: (min: 29, avg: 178.57, max: 500)
#
# Run: 174, exploration: 0.01, score: 175
# Scores: (min: 29, avg: 178.83, max: 500)
#
# Run: 175, exploration: 0.01, score: 187
# Scores: (min: 29, avg: 178.88, max: 500)
#
# Run: 176, exploration: 0.01, score: 286
# Scores: (min: 29, avg: 180.63, max: 500)
#
# Run: 177, exploration: 0.01, score: 174
# Scores: (min: 29, avg: 180.61, max: 500)
#
# Run: 178, exploration: 0.01, score: 290
# Scores: (min: 29, avg: 181.77, max: 500)
#
# Run: 179, exploration: 0.01, score: 95
# Scores: (min: 29, avg: 179.97, max: 500)
#
# Run: 180, exploration: 0.01, score: 359
# Scores: (min: 29, avg: 180.72, max: 500)
#
# Run: 181, exploration: 0.01, score: 114
# Scores: (min: 29, avg: 180.42, max: 500)
#
# Run: 182, exploration: 0.01, score: 374
# Scores: (min: 29, avg: 182.25, max: 500)
#
# Run: 183, exploration: 0.01, score: 102
# Scores: (min: 29, avg: 182.23, max: 500)
#
# Run: 184, exploration: 0.01, score: 165
# Scores: (min: 29, avg: 182.91, max: 500)
#
# Run: 185, exploration: 0.01, score: 259
# Scores: (min: 29, avg: 182.68, max: 500)
#
# Run: 186, exploration: 0.01, score: 176
# Scores: (min: 29, avg: 182.5, max: 500)
#
# Run: 187, exploration: 0.01, score: 200
# Scores: (min: 29, avg: 183.46, max: 500)
#
# Run: 188, exploration: 0.01, score: 306
# Scores: (min: 29, avg: 184.86, max: 500)
#
# Run: 189, exploration: 0.01, score: 174
# Scores: (min: 29, avg: 185.61, max: 500)
#
# Run: 190, exploration: 0.01, score: 370
# Scores: (min: 29, avg: 187.85, max: 500)
#
# Run: 191, exploration: 0.01, score: 44
# Scores: (min: 29, avg: 186.93, max: 500)
#
# Run: 192, exploration: 0.01, score: 203
# Scores: (min: 29, avg: 187.65, max: 500)
#
# Run: 193, exploration: 0.01, score: 360
# Scores: (min: 29, avg: 189.33, max: 500)
#
# Run: 194, exploration: 0.01, score: 150
# Scores: (min: 29, avg: 189.24, max: 500)
#
# Run: 195, exploration: 0.01, score: 268
# Scores: (min: 29, avg: 190.39, max: 500)
#
# Run: 196, exploration: 0.01, score: 182
# Scores: (min: 29, avg: 190.93, max: 500)
#
# Run: 197, exploration: 0.01, score: 187
# Scores: (min: 29, avg: 190.98, max: 500)
#
# Run: 198, exploration: 0.01, score: 287
# Scores: (min: 29, avg: 190.95, max: 500)
#
# Run: 199, exploration: 0.01, score: 273
# Scores: (min: 29, avg: 192, max: 500)
#
# Run: 200, exploration: 0.01, score: 211
# Scores: (min: 29, avg: 192.02, max: 500)
#
# Run: 201, exploration: 0.01, score: 217
# Scores: (min: 29, avg: 193.42, max: 500)
#
# Run: 202, exploration: 0.01, score: 89
# Scores: (min: 29, avg: 191.77, max: 500)
#
# Run: 203, exploration: 0.01, score: 346
# Scores: (min: 29, avg: 193.13, max: 500)
#
# Run: 204, exploration: 0.01, score: 157
# Scores: (min: 29, avg: 193.17, max: 500)
#
# Run: 205, exploration: 0.01, score: 402
# Scores: (min: 29, avg: 195.64, max: 500)
#
# Solved in 105 runs, 205 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-e23913c48dc8> in <module>
# ----> 1 cartpole()
#
# <ipython-input-21-a188bc5c71ff> in cartpole()
#      85             if terminal:
#      86                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
# ---> 87                 score_logger.add_score(step, run)
#      88                 break
#      89             dqn_solver.experience_replay()
#
# U:\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_trend=False,
#      53             #               show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined
