# %% [markdown]
# # Module Five Assignment: Cartpole Problem
# Review the code in this notebook and in the score_logger.py file in the *scores* folder (directory). Once you have reviewed the code, return to this notebook and select **Cell** and then **Run All** from the menu bar to run this code. The code takes several minutes to run.

# %% [markdown]
# Note: If the code is running properly, you should begin to see output appearing above this code block. It will take several minutes, so it is recommended that you let this code run in the background while completing other work. When the code has finished, it will print output saying, "Solved in _ runs, _ total runs."
#
# You may see an error about not having an exit command. This error does not affect the program's functionality and results from the steps taken to convert the code from Python 2.x to Python 3. Please disregard this error.

# %%
# modifying exploration 
# Solved in 38 runs, 138 total runs.
# exploration factor = comb EXPLORATION_MAX, EXPLORATION_MIN, and #EXPLORATION_DECAY

import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  
  
  
from scores.score_logger import ScoreLogger  

ENV_NAME = "CartPole-v1"  
  
GAMMA = 0.95  
LEARNING_RATE = 0.001  
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 20  
  
EXPLORATION_MAX = .5 
EXPLORATION_MIN = .01 # increcreased from 0.01
EXPLORATION_DECAY = .999  # decreased from 0.995

class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()

# %%
 cartpole()
# Out:
# Run: 1, exploration: 0.4980029980005, score: 24
# Scores: (min: 24, avg: 24, max: 24)
#
# Run: 2, exploration: 0.49255227318100103, score: 12
# Scores: (min: 12, avg: 18, max: 24)
#
# Run: 3, exploration: 0.48862561891072587, score: 9
# Scores: (min: 9, avg: 15, max: 24)
#
# Run: 4, exploration: 0.48327753104954174, score: 12
# Scores: (min: 9, avg: 14.25, max: 24)
#
# Run: 5, exploration: 0.4765554484399472, score: 15
# Scores: (min: 9, avg: 14.4, max: 24)
#
# Run: 6, exploration: 0.4592366112079743, score: 38
# Scores: (min: 9, avg: 18.333333333333332, max: 38)
#
# Run: 7, exploration: 0.4560315828411362, score: 8
# Scores: (min: 8, avg: 16.857142857142858, max: 38)
#
# Run: 8, exploration: 0.45149173380581464, score: 11
# Scores: (min: 8, avg: 16.125, max: 38)
#
# Run: 9, exploration: 0.4474445240355048, score: 10
# Scores: (min: 8, avg: 15.444444444444445, max: 38)
#
# Run: 10, exploration: 0.44432179305735386, score: 8
# Scores: (min: 8, avg: 14.7, max: 38)
#
# Run: 11, exploration: 0.43989851638204847, score: 11
# Scores: (min: 8, avg: 14.363636363636363, max: 38)
#
# Run: 12, exploration: 0.43639162080590216, score: 9
# Scores: (min: 8, avg: 13.916666666666666, max: 38)
#
# Run: 13, exploration: 0.43075244378530375, score: 14
# Scores: (min: 8, avg: 13.923076923076923, max: 38)
#
# Run: 14, exploration: 0.42603778735586995, score: 12
# Scores: (min: 8, avg: 13.785714285714286, max: 38)
#
# Run: 15, exploration: 0.4205324055249196, score: 14
# Scores: (min: 8, avg: 13.8, max: 38)
#
# Run: 16, exploration: 0.41634595505223626, score: 11
# Scores: (min: 8, avg: 13.625, max: 38)
#
# Run: 17, exploration: 0.4113771910342946, score: 13
# Scores: (min: 8, avg: 13.588235294117647, max: 38)
#
# Run: 18, exploration: 0.383168564937984, score: 72
# Scores: (min: 8, avg: 16.833333333333332, max: 72)
#
# Run: 19, exploration: 0.35157813650051745, score: 87
# Scores: (min: 8, avg: 20.526315789473685, max: 87)
#
# Run: 20, exploration: 0.32130375436631414, score: 91
# Scores: (min: 8, avg: 24.05, max: 91)
#
# Run: 21, exploration: 0.30077242899897155, score: 67
# Scores: (min: 8, avg: 26.095238095238095, max: 91)
#
# Run: 22, exploration: 0.27763683264644345, score: 81
# Scores: (min: 8, avg: 28.59090909090909, max: 91)
#
# Run: 23, exploration: 0.26198437980717554, score: 59
# Scores: (min: 8, avg: 29.91304347826087, max: 91)
#
# Run: 24, exploration: 0.2489518155557218, score: 52
# Scores: (min: 8, avg: 30.833333333333332, max: 91)
#
# Run: 25, exploration: 0.23095475854723085, score: 76
# Scores: (min: 8, avg: 32.64, max: 91)
#
# Run: 26, exploration: 0.21149002019638505, score: 89
# Scores: (min: 8, avg: 34.80769230769231, max: 91)
#
# Run: 27, exploration: 0.19212184488336834, score: 97
# Scores: (min: 8, avg: 37.111111111111114, max: 97)
#
# Run: 28, exploration: 0.18403174412961137, score: 44
# Scores: (min: 8, avg: 37.357142857142854, max: 97)
#
# Run: 29, exploration: 0.16584543339746557, score: 105
# Scores: (min: 8, avg: 39.689655172413794, max: 105)
#
# Run: 30, exploration: 0.14885939377197582, score: 109
# Scores: (min: 8, avg: 42, max: 109)
#
# Run: 31, exploration: 0.14074843891550887, score: 57
# Scores: (min: 8, avg: 42.483870967741936, max: 109)
#
# Run: 32, exploration: 0.13455212369848218, score: 46
# Scores: (min: 8, avg: 42.59375, max: 109)
#
# Run: 33, exploration: 0.12321214569233088, score: 89
# Scores: (min: 8, avg: 44, max: 109)
#
# Run: 34, exploration: 0.11649864158516128, score: 57
# Scores: (min: 8, avg: 44.38235294117647, max: 109)
#
# Run: 35, exploration: 0.10949168300092059, score: 63
# Scores: (min: 8, avg: 44.91428571428571, max: 109)
#
# Run: 36, exploration: 0.09956404051078807, score: 96
# Scores: (min: 8, avg: 46.333333333333336, max: 109)
#
# Run: 37, exploration: 0.09329518871916495, score: 66
# Scores: (min: 8, avg: 46.86486486486486, max: 109)
#
# Run: 38, exploration: 0.08945605728533486, score: 43
# Scores: (min: 8, avg: 46.76315789473684, max: 109)
#
# Run: 39, exploration: 0.082409975979909, score: 83
# Scores: (min: 8, avg: 47.69230769230769, max: 109)
#
# Run: 40, exploration: 0.07411763268411493, score: 107
# Scores: (min: 8, avg: 49.175, max: 109)
#
# Run: 41, exploration: 0.06560109718869617, score: 123
# Scores: (min: 8, avg: 50.97560975609756, max: 123)
#
# Run: 42, exploration: 0.05847123260140005, score: 116
# Scores: (min: 8, avg: 52.523809523809526, max: 123)
#
# Run: 43, exploration: 0.05139137412782626, score: 130
# Scores: (min: 8, avg: 54.325581395348834, max: 130)
#
# Run: 44, exploration: 0.046638286732214575, score: 98
# Scores: (min: 8, avg: 55.31818181818182, max: 130)
#
# Run: 45, exploration: 0.03475330618230999, score: 295
# Scores: (min: 8, avg: 60.644444444444446, max: 295)
#
# Run: 46, exploration: 0.033523835638144754, score: 37
# Scores: (min: 8, avg: 60.130434782608695, max: 295)
#
# Run: 47, exploration: 0.0270084188148307, score: 217
# Scores: (min: 8, avg: 63.46808510638298, max: 295)
#
# Run: 48, exploration: 0.02540937257585332, score: 62
# Scores: (min: 8, avg: 63.4375, max: 295)
#
# Run: 49, exploration: 0.019048226667859203, score: 289
# Scores: (min: 8, avg: 68.04081632653062, max: 295)
#
# Run: 50, exploration: 0.01559380846528666, score: 201
# Scores: (min: 8, avg: 70.7, max: 295)
#
# Run: 51, exploration: 0.01, score: 465
# Scores: (min: 8, avg: 78.43137254901961, max: 465)
#
# Run: 52, exploration: 0.01, score: 175
# Scores: (min: 8, avg: 80.28846153846153, max: 465)
#
# Run: 53, exploration: 0.01, score: 179
# Scores: (min: 8, avg: 82.15094339622641, max: 465)
#
# Run: 54, exploration: 0.01, score: 237
# Scores: (min: 8, avg: 85.01851851851852, max: 465)
#
# Run: 55, exploration: 0.01, score: 246
# Scores: (min: 8, avg: 87.94545454545455, max: 465)
#
# Run: 56, exploration: 0.01, score: 286
# Scores: (min: 8, avg: 91.48214285714286, max: 465)
#
# Run: 57, exploration: 0.01, score: 187
# Scores: (min: 8, avg: 93.15789473684211, max: 465)
#
# Run: 58, exploration: 0.01, score: 195
# Scores: (min: 8, avg: 94.91379310344827, max: 465)
#
# Run: 59, exploration: 0.01, score: 195
# Scores: (min: 8, avg: 96.61016949152543, max: 465)
#
# Run: 60, exploration: 0.01, score: 167
# Scores: (min: 8, avg: 97.78333333333333, max: 465)
#
# Run: 61, exploration: 0.01, score: 181
# Scores: (min: 8, avg: 99.14754098360656, max: 465)
#
# Run: 62, exploration: 0.01, score: 185
# Scores: (min: 8, avg: 100.53225806451613, max: 465)
#
# Run: 63, exploration: 0.01, score: 164
# Scores: (min: 8, avg: 101.53968253968254, max: 465)
#
# Run: 64, exploration: 0.01, score: 198
# Scores: (min: 8, avg: 103.046875, max: 465)
#
# Run: 65, exploration: 0.01, score: 215
# Scores: (min: 8, avg: 104.76923076923077, max: 465)
#
# Run: 66, exploration: 0.01, score: 170
# Scores: (min: 8, avg: 105.75757575757575, max: 465)
#
# Run: 67, exploration: 0.01, score: 263
# Scores: (min: 8, avg: 108.1044776119403, max: 465)
#
# Run: 68, exploration: 0.01, score: 215
# Scores: (min: 8, avg: 109.67647058823529, max: 465)
#
# Run: 69, exploration: 0.01, score: 221
# Scores: (min: 8, avg: 111.28985507246377, max: 465)
#
# Run: 70, exploration: 0.01, score: 141
# Scores: (min: 8, avg: 111.71428571428571, max: 465)
#
# Run: 71, exploration: 0.01, score: 352
# Scores: (min: 8, avg: 115.09859154929578, max: 465)
#
# Run: 72, exploration: 0.01, score: 248
# Scores: (min: 8, avg: 116.94444444444444, max: 465)
#
# Run: 73, exploration: 0.01, score: 245
# Scores: (min: 8, avg: 118.6986301369863, max: 465)
#
# Run: 74, exploration: 0.01, score: 183
# Scores: (min: 8, avg: 119.56756756756756, max: 465)
#
# Run: 75, exploration: 0.01, score: 184
# Scores: (min: 8, avg: 120.42666666666666, max: 465)
#
# Run: 76, exploration: 0.01, score: 237
# Scores: (min: 8, avg: 121.96052631578948, max: 465)
#
# Run: 77, exploration: 0.01, score: 254
# Scores: (min: 8, avg: 123.67532467532467, max: 465)
#
# Run: 78, exploration: 0.01, score: 254
# Scores: (min: 8, avg: 125.34615384615384, max: 465)
#
# Run: 79, exploration: 0.01, score: 171
# Scores: (min: 8, avg: 125.92405063291139, max: 465)
#
# Run: 80, exploration: 0.01, score: 227
# Scores: (min: 8, avg: 127.1875, max: 465)
#
# Run: 81, exploration: 0.01, score: 177
# Scores: (min: 8, avg: 127.80246913580247, max: 465)
#
# Run: 82, exploration: 0.01, score: 218
# Scores: (min: 8, avg: 128.90243902439025, max: 465)
#
# Run: 83, exploration: 0.01, score: 219
# Scores: (min: 8, avg: 129.9879518072289, max: 465)
#
# Run: 84, exploration: 0.01, score: 259
# Scores: (min: 8, avg: 131.52380952380952, max: 465)
#
# Run: 85, exploration: 0.01, score: 231
# Scores: (min: 8, avg: 132.69411764705882, max: 465)
#
# Run: 86, exploration: 0.01, score: 233
# Scores: (min: 8, avg: 133.86046511627907, max: 465)
#
# Run: 87, exploration: 0.01, score: 258
# Scores: (min: 8, avg: 135.28735632183907, max: 465)
#
# Run: 88, exploration: 0.01, score: 198
# Scores: (min: 8, avg: 136, max: 465)
#
# Run: 89, exploration: 0.01, score: 188
# Scores: (min: 8, avg: 136.58426966292134, max: 465)
#
# Run: 90, exploration: 0.01, score: 185
# Scores: (min: 8, avg: 137.12222222222223, max: 465)
#
# Run: 91, exploration: 0.01, score: 280
# Scores: (min: 8, avg: 138.69230769230768, max: 465)
#
# Run: 92, exploration: 0.01, score: 193
# Scores: (min: 8, avg: 139.2826086956522, max: 465)
#
# Run: 93, exploration: 0.01, score: 225
# Scores: (min: 8, avg: 140.20430107526883, max: 465)
#
# Run: 94, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 138.81914893617022, max: 465)
#
# Run: 95, exploration: 0.01, score: 181
# Scores: (min: 8, avg: 139.26315789473685, max: 465)
#
# Run: 96, exploration: 0.01, score: 198
# Scores: (min: 8, avg: 139.875, max: 465)
#
# Run: 97, exploration: 0.01, score: 195
# Scores: (min: 8, avg: 140.44329896907217, max: 465)
#
# Run: 98, exploration: 0.01, score: 197
# Scores: (min: 8, avg: 141.0204081632653, max: 465)
#
# Run: 99, exploration: 0.01, score: 357
# Scores: (min: 8, avg: 143.2020202020202, max: 465)
#
# Run: 100, exploration: 0.01, score: 235
# Scores: (min: 8, avg: 144.12, max: 465)
#
# Run: 101, exploration: 0.01, score: 222
# Scores: (min: 8, avg: 146.1, max: 465)
#
# Run: 102, exploration: 0.01, score: 193
# Scores: (min: 8, avg: 147.91, max: 465)
#
# Run: 103, exploration: 0.01, score: 209
# Scores: (min: 8, avg: 149.91, max: 465)
#
# Run: 104, exploration: 0.01, score: 170
# Scores: (min: 8, avg: 151.49, max: 465)
#
# Run: 105, exploration: 0.01, score: 199
# Scores: (min: 8, avg: 153.33, max: 465)
#
# Run: 106, exploration: 0.01, score: 224
# Scores: (min: 8, avg: 155.19, max: 465)
#
# Run: 107, exploration: 0.01, score: 145
# Scores: (min: 8, avg: 156.56, max: 465)
#
# Run: 108, exploration: 0.01, score: 119
# Scores: (min: 8, avg: 157.64, max: 465)
#
# Run: 109, exploration: 0.01, score: 276
# Scores: (min: 8, avg: 160.3, max: 465)
#
# Run: 110, exploration: 0.01, score: 356
# Scores: (min: 9, avg: 163.78, max: 465)
#
# Run: 111, exploration: 0.01, score: 20
# Scores: (min: 9, avg: 163.87, max: 465)
#
# Run: 112, exploration: 0.01, score: 20
# Scores: (min: 10, avg: 163.98, max: 465)
#
# Run: 113, exploration: 0.01, score: 105
# Scores: (min: 10, avg: 164.89, max: 465)
#
# Run: 114, exploration: 0.01, score: 132
# Scores: (min: 10, avg: 166.09, max: 465)
#
# Run: 115, exploration: 0.01, score: 150
# Scores: (min: 10, avg: 167.45, max: 465)
#
# Run: 116, exploration: 0.01, score: 226
# Scores: (min: 10, avg: 169.6, max: 465)
#
# Run: 117, exploration: 0.01, score: 235
# Scores: (min: 10, avg: 171.82, max: 465)
#
# Run: 118, exploration: 0.01, score: 193
# Scores: (min: 10, avg: 173.03, max: 465)
#
# Run: 119, exploration: 0.01, score: 176
# Scores: (min: 10, avg: 173.92, max: 465)
#
# Run: 120, exploration: 0.01, score: 148
# Scores: (min: 10, avg: 174.49, max: 465)
#
# Run: 121, exploration: 0.01, score: 71
# Scores: (min: 10, avg: 174.53, max: 465)
#
# Run: 122, exploration: 0.01, score: 172
# Scores: (min: 10, avg: 175.44, max: 465)
#
# Run: 123, exploration: 0.01, score: 158
# Scores: (min: 10, avg: 176.43, max: 465)
#
# Run: 124, exploration: 0.01, score: 217
# Scores: (min: 10, avg: 178.08, max: 465)
#
# Run: 125, exploration: 0.01, score: 142
# Scores: (min: 10, avg: 178.74, max: 465)
#
# Run: 126, exploration: 0.01, score: 215
# Scores: (min: 10, avg: 180, max: 465)
#
# Run: 127, exploration: 0.01, score: 261
# Scores: (min: 10, avg: 181.64, max: 465)
#
# Run: 128, exploration: 0.01, score: 159
# Scores: (min: 10, avg: 182.79, max: 465)
#
# Run: 129, exploration: 0.01, score: 182
# Scores: (min: 10, avg: 183.56, max: 465)
#
# Run: 130, exploration: 0.01, score: 171
# Scores: (min: 10, avg: 184.18, max: 465)
#
# Run: 131, exploration: 0.01, score: 184
# Scores: (min: 10, avg: 185.45, max: 465)
#
# Run: 132, exploration: 0.01, score: 265
# Scores: (min: 10, avg: 187.64, max: 465)
#
# Run: 133, exploration: 0.01, score: 224
# Scores: (min: 10, avg: 188.99, max: 465)
#
# Run: 134, exploration: 0.01, score: 166
# Scores: (min: 10, avg: 190.08, max: 465)
#
# Run: 135, exploration: 0.01, score: 158
# Scores: (min: 10, avg: 191.03, max: 465)
#
# Run: 136, exploration: 0.01, score: 223
# Scores: (min: 10, avg: 192.3, max: 465)
#
# Run: 137, exploration: 0.01, score: 251
# Scores: (min: 10, avg: 194.15, max: 465)
#
# Run: 138, exploration: 0.01, score: 155
# Scores: (min: 10, avg: 195.27, max: 465)
#
# Solved in 38 runs, 138 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-e23913c48dc8> in <module>
# ----> 1 cartpole()
#
# <ipython-input-11-937716510cad> in cartpole()
#      99             if terminal:
#     100                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
# --> 101                 score_logger.add_score(step, run)
#     102                 break
#     103             dqn_solver.experience_replay()
#
# U:\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_trend=False,
#      53             #               show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined
